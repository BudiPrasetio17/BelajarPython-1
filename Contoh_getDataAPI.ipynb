# %% [markdown]
# <a href="https://colab.research.google.com/github/BudiPrasetio17/BelajarPython-1/blob/main/Contoh_getDataAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from urllib import request

api_url = 'https://indonesia-covid-19.mathdro.id/api/provinsi' #alamat API

#lakukan http request
response = request.urlopen(api_url)

#parsing data json
data = json.loads(response.read())

#gunakan perulangan untuk menampilkan data
for covid in data['data']:
  print(f"- {covid['provinsi']}:")
  print(f" *Positif  :{covid['kasusPosi']}")
  print(f" *Negatif  :{covid['kasusSemb']}")
  print(f" *Meninggal:{covid['kasusMeni']}")
# Out:
# - DKI Jakarta:
#  *Positif  :406205
#  *Negatif  :393166
#  *Meninggal:6625
# - Jawa Barat:
#  *Positif  :277553
#  *Negatif  :243650
#  *Meninggal:3678
# - Jawa Tengah:
#  *Positif  :183027
#  *Negatif  :162823
#  *Meninggal:8001
# - Jawa Timur:
#  *Positif  :146808
#  *Negatif  :134525
#  *Meninggal:10600
# - Kalimantan Timur:
#  *Positif  :68136
#  *Negatif  :64718
#  *Meninggal:1631
# - Sulawesi Selatan:
#  *Positif  :61419
#  *Negatif  :60164
#  *Meninggal:931
# - Banten:
#  *Positif  :47101
#  *Negatif  :43892
#  *Meninggal:1200
# - Bali:
#  *Positif  :44236
#  *Negatif  :41608
#  *Meninggal:1317
# - Riau:
#  *Positif  :42698
#  *Negatif  :37374
#  *Meninggal:1050
# - Daerah Istimewa Yogyakarta:
#  *Positif  :38703
#  *Negatif  :33636
#  *Meninggal:948
# - Sumatera Barat:
#  *Positif  :36268
#  *Negatif  :33058
#  *Meninggal:783
# - Kalimantan Selatan:
#  *Positif  :32612
#  *Negatif  :29518
#  *Meninggal:937
# - Sumatera Utara:
#  *Positif  :29198
#  *Negatif  :25952
# ...
